# %% [markdown]
# # Performance analysis of straight and curved diffuser

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Straight diffuser

# %% [markdown]
# ### opening position 1

# %%
Op1 = [-0.941950199,
       -0.790106523,
       -0.642161904,
       -0.618191725,
       -0.533461855,
       -0.911169889,
       -0.79676143,
       -0.700274467,
       -0.606546513,
       -0.528816928
       ]

# %% [markdown]
# ### opening position 2

# %%
Op2 = [-0.938852315,
       -0.803643715,
       -0.697044115,
       -0.625100068,
       -0.521615879,
       -0.922690339,
       -0.798864553,
       -0.713072248,
       -0.614272081,
       -0.535431193
       ]

# %% [markdown]
# ### opening position 3

# %%
Op3 = [-0.932192121,
       -0.800755005,
       -0.695106827,
       -0.624962821,
       -0.519680179,
       -0.922857281,
       -0.8021845,
       -0.70903232,
       -0.611189573,
       -0.535888745
       ]

# %%
plt.figure(figsize=(16,5));
plt.subplot(131);
plt.plot(Op1[:5],'-o')
plt.plot(Op1[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 1")
plt.subplot(132);
plt.plot(Op2[:5],'-o')
plt.plot(Op2[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 2")
plt.subplot(133);
plt.plot(Op3[:5],'-o')
plt.plot(Op3[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 3")
# Out:
# Text(0.5, 1.0, 'Opening position 3')

# %% [markdown]
# ## Curved diffuser

# %% [markdown]
# ### opening position 1

# %%
Cop1 = [-1.064448379,
        - 0.940131449,
        - 0.775679687,
        - 0.676672546,
        - 0.649939912,
        - 0.701741447,
        - 0.519093606,
        - 0.459599014,
        - 0.39777655,
        - 0.433575094
        ]

# %% [markdown]
# ### opening position 2

# %%
Cop2 = [-1.045566686,
        -0.924996635,
        -0.763234887,
        -0.655222196,
        -0.628318623,
        -0.702901259,
        -0.571932975,
        -0.504306684,
        -0.436274752,
        -0.461053915
        ]

# %% [markdown]
# ### opening position 3

# %%
Cop3 = [-1.057709612,
        -0.938639574,
        -0.777182121,
        -0.671124327,
        -0.644147687,
        -0.71842358,
        -0.586762005,
        -0.550070862,
        -0.444240576,
        -0.472132852
        ]

# %%
plt.figure(figsize=(16,5));
plt.subplot(131);
plt.plot(Cop1[:5],'-o')
plt.plot(Cop1[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 1")
plt.subplot(132);
plt.plot(Cop2[:5],'-o')
plt.plot(Cop2[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 2")
plt.subplot(133);
plt.plot(Cop3[:5],'-o')
plt.plot(Cop3[5:],"-s");
plt.xticks(np.arange(5),['1/6','2/7','3/8','4/9','5/10']);
plt.xlabel("Tap Numbers");plt.ylabel("Cp");plt.grid();plt.legend(['1-5',"6-10"]);plt.title("Opening position 3")
# Out:
# Text(0.5, 1.0, 'Opening position 3')
